# %%
from nsdesolve import simulate_2d_only_memory_anharmonic_1
import numpy as np

# %%
N=50
warmup=0
dt=0.001
samples=20
skip=1
runs=4

# %%
simulate_2d_only_memory_anharmonic_1(x0=np.zeros(samples),y0=np.zeros(samples),
                  vx0=np.zeros(samples),vy0=np.zeros(samples),
        N=N, samples=samples,
        dt=dt, warmup=warmup, skip=skip,
        A=-1,B=0,gamma0=1,b=2, kappa=3)
# Out:
# (array([[ 0.00000000e+00, -1.66208357e-05, -7.40353016e-05,
#          -1.51518875e-04, -1.58966812e-04, -2.02941856e-04,
#          -2.59947326e-04, -3.39744314e-04, -3.71895706e-04,
#          -4.35158741e-04, -4.58913173e-04, -4.77167402e-04,
#          -4.98229243e-04, -5.42668140e-04, -5.52509211e-04,
#          -5.64182500e-04, -5.82231662e-04, -5.84387773e-04,
#          -5.96561653e-04, -5.73611563e-04, -6.21205020e-04,
#          -6.27527643e-04, -6.44616586e-04, -7.18212374e-04,
#          -8.41658311e-04, -1.02282180e-03, -1.19264808e-03,
#          -1.35259937e-03, -1.49068142e-03, -1.60297236e-03,
#          -1.72782513e-03, -1.81329880e-03, -1.94589392e-03,
#          -2.08080558e-03, -2.22889371e-03, -2.39335680e-03,
#          -2.51518920e-03, -2.68193349e-03, -2.82691314e-03,
#          -2.99125652e-03, -3.18414052e-03, -3.40725594e-03,
#          -3.63284105e-03, -3.89237081e-03, -4.17138962e-03,
#          -4.41870023e-03, -4.63261378e-03, -4.85223267e-03,
# ...
